# %%
import os
import h5py
import matplotlib.pyplot as plt
import numpy as np

import sys
sys.path.append("../")

from scripts.image import ImageDiagnostic


data_dir = "/home/physics/ml_tuning/20240225_LCLS_II_Injector/"


files = os.listdir(data_dir)
files =["/home/physics/ml_tuning/20240225_LCLS_II_Injector/OTRS_HTR_330_1708933824.h5",
    "/home/physics/ml_tuning/20240225_LCLS_II_Injector/OTRS_HTR_330_1708933827.h5",
    "/home/physics/ml_tuning/20240225_LCLS_II_Injector/OTRS_HTR_330_1708933831.h5",
    "/home/physics/ml_tuning/20240225_LCLS_II_Injector/OTRS_HTR_330_1708933834.h5",
    "/home/physics/ml_tuning/20240225_LCLS_II_Injector/OTRS_HTR_330_1708933838.h5",
    "/home/physics/ml_tuning/20240225_LCLS_II_Injector/OTRS_HTR_330_1708933841.h5",
    "/home/physics/ml_tuning/20240225_LCLS_II_Injector/OTRS_HTR_330_1708933845.h5",
    "/home/physics/ml_tuning/20240225_LCLS_II_Injector/OTRS_HTR_330_1708933848.h5",
    "/home/physics/ml_tuning/20240225_LCLS_II_Injector/OTRS_HTR_330_1708933852.h5",
    "/home/physics/ml_tuning/20240225_LCLS_II_Injector/OTRS_HTR_330_1708933855.h5"]

diagnostic = ImageDiagnostic(screen_name="test",n_fitting_restarts=20)
size = []
for name in files:
    
    with h5py.File(name) as f:
        img = f["images"][0]
      
    res = diagnostic.calculate_beamsize(img, img)
    size += [[res["Sx"]**2,res["Sy"]**2]]
    
    #diagnostic.test_measurement()
    
data = np.array(size)
import matplotlib.pyplot as plt
plt.figure()
plt.plot(data)
# Out:
# displaying image
# fitting image
# tensor([9.7844e-01, 1.1120e+03, 1.9440e+02, 2.1560e-02], dtype=torch.float64)
# tensor([8.2322e-01, 6.6200e+02, 1.4720e+02, 1.7678e-01], dtype=torch.float64)
# {'Cx': 1110.5988966131104,
#  'Cy': 693.598800111964,
#  'Sx': 12.906960512066368,
#  'Sy': 86.52531554899764,
#  'bb_penalty': -224.11775178383772,
#  'log10_total_intensity': 5.815043516567927,
#  'total_intensity': 653196.0}
# displaying image
# fitting image
# tensor([9.7442e-01, 1.0410e+03, 1.9440e+02, 2.5579e-02], dtype=torch.float64)
# tensor([9.1541e-01, 1.0590e+03, 1.4720e+02, 8.4587e-02], dtype=torch.float64)
# {'Cx': 1040.3977838133537,
#  'Cy': 1042.7884436412605,
#  'Sx': 14.147010784289566,
#  'Sy': 32.971586356806,
#  'bb_penalty': -202.24701116518327,
#  'log10_total_intensity': 5.76672358368301,
#  'total_intensity': 584418.0}
# displaying image
# fitting image
# tensor([9.5641e-01, 1.0370e+03, 1.9440e+02, 4.3586e-02], dtype=torch.float64)
# ...

# %%
plt.plot(data[:,0])

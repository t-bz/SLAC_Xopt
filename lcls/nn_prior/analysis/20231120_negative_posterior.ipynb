# %%
import sys

import matplotlib.pyplot as plt

sys.path.append("../")
from utils import load_xopt_data

# %%
data_dir = "../../data/20231120_LCLS_Injector/"

# %%
for i in range(20):
    filename = f"nn_optimization_9d_{i+1}.yml"
    if i + 1 == 3:
        filename = f"nn_optimization_9d_{i+1}_standard.yml"
    df = load_xopt_data(data_dir + filename)
    columns = [
        "total_size" + k for k in ["", "_prior_mean", "_posterior_mean", "_posterior_sd"]
    ]
    ax = df[columns].plot()
    ax.set_title(filename);

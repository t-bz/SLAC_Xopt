# %%
import sys
sys.path
# Out:
# ['/home/physics3/rroussel',
#  '/usr/local/lcls/tools/python/toolbox',
#  '/usr/local/lcls/package/anaconda/envs/rhel7_devel/lib/python39.zip',
#  '/usr/local/lcls/package/anaconda/envs/rhel7_devel/lib/python3.9',
#  '/usr/local/lcls/package/anaconda/envs/rhel7_devel/lib/python3.9/lib-dynload',
#  '',
#  '/home/physics3/.local/lib/python3.9/site-packages',
#  '/usr/local/lcls/package/anaconda/envs/rhel7_devel/lib/python3.9/site-packages']

# %%
from pvmonitor import ImagePvMonitor

# %%
monitor = ImagePvMonitor("OTRS:IN20:621", interval=1.0)

# %%
monitor.run()
